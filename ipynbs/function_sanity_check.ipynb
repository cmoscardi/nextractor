# %%
from radar_utils import load_scans, impute
import matplotlib
# %matplotlib inline

# %%
scan_df = load_scans(["data/09/28/", "data/09/29/"])

# %%
scan_df.Date_Time.value_counts().sort_index().plot(style='-o')

# %%
imputed = impute(scan_df)
imputed.Date_Time.value_counts().sort_index().plot(style='-o')
