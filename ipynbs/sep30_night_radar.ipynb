# %%
from IPython.display import HTML

import matplotlib
# %matplotlib inline

from radar_utils import (load_scans, impute, plot_video, 
                        cut_insects, cut_weather, plot_ts)

# %%
df = load_scans(["data/09/30/", "data/10/01/"])

# %%
df.Date_Time.value_counts().sort_index().plot(style='-o')

# %%
plot_ts(df)

# %%
vid = plot_video(df)
vid.save("sep30_full.mp4")
# Out:
# /home/christian/.miniconda2/envs/gdalwtf/lib/python3.6/site-packages/matplotlib/colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
HTML(vid.to_html5_video())
# Out:
# /home/christian/.miniconda2/envs/gdalwtf/lib/python3.6/site-packages/matplotlib/colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <video width="720" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
cut_df = cut_weather(cut_insects(df))
vid = plot_video(df)
#HTML(vid.to_html5_video())
vid.save("sep30_cut.mp4")
# Out:
# /home/christian/.miniconda2/envs/gdalwtf/lib/python3.6/site-packages/matplotlib/colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
plot_ts(cut_df)
